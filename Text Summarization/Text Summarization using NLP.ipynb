# %% [markdown]
# ## Steps Involved in Text Summarization:

# %% [markdown]
# 1) Text cleaning
# 2) Sentence Tokenization
# 3) Word Tokenization
# 4) Word-frequency table
# 5) Summarization.
#
# Text Summarization is converting whole text into medium size which contains only important speech.

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
stopwords = list(STOP_WORDS)
stopwords
# Out:
# ['whatever',
#  'whoever',
#  'off',
#  'your',
#  'too',
#  'fifteen',
#  'give',
#  'least',
#  'along',
#  'full',
#  'there',
#  'anyhow',
#  'if',
#  'although',
#  'top',
#  'not',
#  'did',
#  'wherever',
#  '‘re',
#  'sometime',
#  'namely',
#  'have',
#  'rather',
#  'they',
#  'again',
#  'back',
#  'an',
#  'towards',
#  'against',
#  'might',
#  'six',
#  'empty',
#  'just',
#  're',
#  'am',
#  '‘ll',
#  'perhaps',
#  'amongst',
#  'became',
#  'less',
#  'we',
#  'whereafter',
#  'get',
#  'whence',
#  'then',
#  'always',
#  'often',
#  '’s',
#  'so',
#  'thence',
#  'may',
#  'however',
#  'ours',
#  'under',
#  'well',
#  'call',
#  'into',
#  'yet',
#  'anyway',
#  'whereupon',
#  'both',
#  'enough',
#  'seem',
#  'except',
#  'whereas',
#  'yourselves',
#  'the',
#  'twelve',
#  'latterly',
#  'himself',
#  'a',
#  'about',
#  'it',
#  'yours',
#  'ten',
#  'nine',
#  'by',
#  'must',
#  'keep',
#  'ca',
#  'when',
#  'whether',
#  'is',
#  'move',
#  'already',
#  'be',
#  'bottom',
#  'made',
#  'who',
#  'whom',
#  'moreover',
#  'down',
#  'meanwhile',
#  'else',
#  'somewhere',
#  'their',
#  'them',
#  'she',
#  'go',
#  'nothing',
#  'hereby',
#  '’ve',
#  'seems',
#  '‘m',
#  'few',
#  'say',
#  'nobody',
#  'thereby',
#  'forty',
#  'last',
#  '‘d',
#  'somehow',
#  'per',
#  'he',
#  'hereupon',
#  'you',
#  'n’t',
#  'thereafter',
#  'still',
#  'in',
#  'his',
#  'through',
#  "'s",
#  'becoming',
#  'while',
#  'put',
#  'mine',
#  'hers',
#  'either',
#  'among',
#  'are',
#  'n‘t',
#  'us',
#  'anyone',
#  '’d',
#  'doing',
#  'below',
#  'our',
#  'each',
#  "'d",
#  'nowhere',
#  'besides',
#  'own',
#  'does',
#  'hereafter',
#  'why',
#  'onto',
#  'every',
#  'whose',
#  'had',
#  'someone',
#  'him',
#  'since',
#  'indeed',
#  'eight',
#  'former',
#  'which',
#  'everywhere',
#  'others',
#  'nor',
#  'all',
#  "'ll",
#  'ever',
#  'ourselves',
#  'third',
#  'until',
#  'herein',
#  'should',
#  'has',
#  'further',
#  'its',
#  'via',
#  'anything',
#  'something',
#  'wherein',
#  'as',
#  'more',
#  'only',
#  'within',
#  'show',
#  'than',
#  'together',
#  'and',
#  'become',
#  'i',
#  'my',
#  'serious',
#  'many',
#  'once',
#  'regarding',
#  'this',
#  'before',
#  'neither',
#  'beforehand',
#  'her',
#  'would',
#  'due',
#  'with',
#  'could',
#  'most',
#  'four',
#  '’re',
#  'first',
#  'much',
#  'formerly',
#  'to',
#  'thus',
#  'me',
#  'sixty',
#  'where',
#  'nevertheless',
#  'though',
#  'almost',
#  'such',
#  'also',
#  'during',
#  'therein',
#  'that',
#  'was',
#  'several',
#  '‘ve',
#  'seemed',
#  'above',
#  'on',
#  'see',
#  'after',
#  'for',
#  'over',
#  'at',
#  'elsewhere',
#  'or',
#  'thru',
#  'none',
#  '’m',
#  'very',
#  'mostly',
#  'quite',
#  'take',
#  'will',
#  'cannot',
#  "'m",
#  'but',
#  'throughout',
#  '‘s',
#  'therefore',
#  'using',
#  'beyond',
#  'upon',
#  'those',
#  'itself',
#  'done',
#  'across',
#  'even',
#  'otherwise',
#  'hundred',
#  'between',
#  "'ve",
#  'really',
#  'how',
#  'name',
#  'seeming',
#  'whither',
#  'beside',
#  'make',
#  'because',
#  'never',
#  'latter',
#  'five',
#  'fifty',
#  'here',
#  "n't",
#  'used',
#  'from',
#  'amount',
#  'becomes',
#  'out',
#  'were',
#  'toward',
#  '’ll',
#  'no',
#  'some',
#  'everyone',
#  'front',
#  'please',
#  'three',
#  'whereby',
#  'other',
#  'do',
#  'noone',
#  'twenty',
#  'two',
#  'can',
#  'around',
#  'myself',
#  'without',
#  'various',
#  'themselves',
#  'everything',
#  'what',
#  'whenever',
#  'yourself',
#  'same',
#  'these',
#  'behind',
#  'side',
#  'eleven',
#  'being',
#  'unless',
#  'another',
#  'alone',
#  'been',
#  'any',
#  'sometimes',
#  'thereupon',
#  'one',
#  'afterwards',
#  'part',
#  'whole',
#  'next',
#  'herself',
#  'of',
#  'anywhere',
#  "'re",
#  'up',
#  'hence',
#  'now']

# %%
nlp = spacy.load('en_core_web_sm')

# %%
text = """The self-study lessons in this section are written and organised according to the levels of the Common European Framework of Reference for languages (CEFR).
There are different types of texts and interactive exercises that practise the reading skills you need to do well in your studies, to get ahead at work and to communicate in English in your free time.
This story was really good and exciting with an sudden end. I thought the text message was a joke, thats exactly the reason why I think this kind of text is really interesting. The question is really awesome and difficult.
The input device used for games, the game controller, varies across platforms. Common controllers include gamepads, joysticks, mouse devices, keyboards, the touchscreens of mobile devices, or even a person's body, using a Kinect sensor.
Players view the game on a display device such as a television or computer monitor or sometimes on virtual reality head-mounted display goggles. There are often game sound effects, music and voice actor lines which come from loudspeakers or headphones.
Some games in the 2000s include haptic, vibration-creating effects, force feedback peripherals and virtual reality headsets.
The electronic systems used to play video games are called platforms. Video games are developed and released for one or several platforms and may not be available on others.
Specialized platforms such as arcade games, which present the game in a large, typically coin-operated chassis, were common in the 1980s in video arcades, but declined in popularity as other, more affordable platforms became available. 
These include dedicated devices such as video game consoles, as well as general-purpose computers like a laptop, desktop or handheld computing devices."""

# %%
doc = nlp(text)

# %%
tokens = [token.text for token in doc]
tokens
# Out:
# ['The',
#  'self',
#  '-',
#  'study',
#  'lessons',
#  'in',
#  'this',
#  'section',
#  'are',
#  'written',
#  'and',
#  'organised',
#  'according',
#  'to',
#  'the',
#  'levels',
#  'of',
#  'the',
#  'Common',
#  'European',
#  'Framework',
#  'of',
#  'Reference',
#  'for',
#  'languages',
#  '(',
#  'CEFR',
#  ')',
#  '.',
#  '\n',
#  'There',
#  'are',
#  'different',
#  'types',
#  'of',
#  'texts',
#  'and',
#  'interactive',
#  'exercises',
#  'that',
#  'practise',
#  'the',
#  'reading',
#  'skills',
#  'you',
#  'need',
#  'to',
#  'do',
#  'well',
#  'in',
#  'your',
#  'studies',
#  ',',
#  'to',
#  'get',
#  'ahead',
#  'at',
#  'work',
#  'and',
#  'to',
#  'communicate',
#  'in',
#  'English',
#  'in',
#  'your',
#  'free',
#  'time',
#  '.',
#  '\n',
#  'This',
#  'story',
#  'was',
#  'really',
#  'good',
#  'and',
#  'exciting',
#  'with',
#  'an',
#  'sudden',
#  'end',
#  '.',
#  'I',
#  'thought',
#  'the',
#  'text',
#  'message',
#  'was',
#  'a',
#  'joke',
#  ',',
#  'that',
#  's',
#  'exactly',
#  'the',
#  'reason',
#  'why',
#  'I',
#  'think',
#  'this',
#  'kind',
#  'of',
#  'text',
#  'is',
#  'really',
#  'interesting',
#  '.',
#  'The',
#  'question',
#  'is',
#  'really',
#  'awesome',
#  'and',
#  'difficult',
#  '.',
#  '\n',
#  'The',
#  'input',
#  'device',
#  'used',
#  'for',
#  'games',
#  ',',
#  'the',
#  'game',
#  'controller',
#  ',',
#  'varies',
#  'across',
#  'platforms',
#  '.',
#  'Common',
#  'controllers',
#  'include',
#  'gamepads',
#  ',',
#  'joysticks',
#  ',',
#  'mouse',
#  'devices',
#  ',',
#  'keyboards',
#  ',',
#  'the',
#  'touchscreens',
#  'of',
#  'mobile',
#  'devices',
#  ',',
#  'or',
#  'even',
#  'a',
#  'person',
#  "'s",
#  'body',
#  ',',
#  'using',
#  'a',
#  'Kinect',
#  'sensor',
#  '.',
#  '\n',
#  'Players',
#  'view',
#  'the',
#  'game',
#  'on',
#  'a',
#  'display',
#  'device',
#  'such',
#  'as',
#  'a',
#  'television',
#  'or',
#  'computer',
#  'monitor',
#  'or',
#  'sometimes',
#  'on',
#  'virtual',
#  'reality',
#  'head',
#  '-',
#  'mounted',
#  'display',
#  'goggles',
#  '.',
#  'There',
#  'are',
#  'often',
#  'game',
#  'sound',
#  'effects',
#  ',',
#  'music',
#  'and',
#  'voice',
#  'actor',
#  'lines',
#  'which',
#  'come',
#  'from',
#  'loudspeakers',
#  'or',
#  'headphones',
#  '.',
#  '\n',
#  'Some',
#  'games',
#  'in',
#  'the',
#  '2000s',
#  'include',
#  'haptic',
#  ',',
#  'vibration',
#  '-',
#  'creating',
#  'effects',
#  ',',
#  'force',
#  'feedback',
#  'peripherals',
#  'and',
#  'virtual',
#  'reality',
#  'headsets',
#  '.',
#  '\n',
#  'The',
#  'electronic',
#  'systems',
#  'used',
#  'to',
#  'play',
#  'video',
#  'games',
#  'are',
#  'called',
#  'platforms',
#  '.',
#  'Video',
#  'games',
#  'are',
#  'developed',
#  'and',
#  'released',
#  'for',
#  'one',
#  'or',
#  'several',
#  'platforms',
#  'and',
#  'may',
#  'not',
#  'be',
#  'available',
#  'on',
#  'others',
#  '.',
#  '\n',
#  'Specialized',
#  'platforms',
#  'such',
#  'as',
#  'arcade',
#  'games',
#  ',',
#  'which',
#  'present',
#  'the',
#  'game',
#  'in',
#  'a',
#  'large',
#  ',',
#  'typically',
#  'coin',
#  '-',
#  'operated',
#  'chassis',
#  ',',
#  'were',
#  'common',
#  'in',
#  'the',
#  '1980s',
#  'in',
#  'video',
#  'arcades',
#  ',',
#  'but',
#  'declined',
#  'in',
#  'popularity',
#  'as',
#  'other',
#  ',',
#  'more',
#  'affordable',
#  'platforms',
#  'became',
#  'available',
#  '.',
#  '\n',
#  'These',
#  'include',
#  'dedicated',
#  'devices',
#  'such',
#  'as',
#  'video',
#  'game',
#  'consoles',
#  ',',
#  'as',
#  'well',
#  'as',
#  'general',
#  '-',
#  'purpose',
#  'computers',
#  'like',
#  'a',
#  'laptop',
#  ',',
#  'desktop',
#  'or',
#  'handheld',
#  'computing',
#  'devices',
#  '.']

# %%
#here we are adding '\n' in punctuation..
punctuation += '\n'
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~\n'

# %%
word_frequencies = {}
for word in doc:
    if word.text.lower() not in stopwords:
        if word.text.lower() not in punctuation:
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text] = 1
            else:
                word_frequencies[word.text]+=1

# %%
word_frequencies
# Out:
# {'self': 1,
#  'study': 1,
#  'lessons': 1,
#  'section': 1,
#  'written': 1,
#  'organised': 1,
#  'according': 1,
#  'levels': 1,
#  'Common': 2,
#  'European': 1,
#  'Framework': 1,
#  'Reference': 1,
#  'languages': 1,
#  'CEFR': 1,
#  'different': 1,
#  'types': 1,
#  'texts': 1,
#  'interactive': 1,
#  'exercises': 1,
#  'practise': 1,
#  'reading': 1,
#  'skills': 1,
#  'need': 1,
#  'studies': 1,
#  'ahead': 1,
#  'work': 1,
#  'communicate': 1,
#  'English': 1,
#  'free': 1,
#  'time': 1,
#  'story': 1,
#  'good': 1,
#  'exciting': 1,
#  'sudden': 1,
#  'end': 1,
#  'thought': 1,
#  'text': 2,
#  'message': 1,
#  'joke': 1,
#  's': 1,
#  'exactly': 1,
#  'reason': 1,
#  'think': 1,
#  'kind': 1,
#  'interesting': 1,
#  'question': 1,
#  'awesome': 1,
#  'difficult': 1,
#  'input': 1,
#  'device': 2,
#  'games': 5,
#  'game': 5,
#  'controller': 1,
#  'varies': 1,
#  'platforms': 5,
#  'controllers': 1,
#  'include': 3,
#  'gamepads': 1,
#  'joysticks': 1,
#  'mouse': 1,
#  'devices': 4,
#  'keyboards': 1,
#  'touchscreens': 1,
#  'mobile': 1,
#  'person': 1,
#  'body': 1,
#  'Kinect': 1,
#  'sensor': 1,
#  'Players': 1,
#  'view': 1,
#  'display': 2,
#  'television': 1,
#  'computer': 1,
#  'monitor': 1,
#  'virtual': 2,
#  'reality': 2,
#  'head': 1,
#  'mounted': 1,
#  'goggles': 1,
#  'sound': 1,
#  'effects': 2,
#  'music': 1,
#  'voice': 1,
#  'actor': 1,
#  'lines': 1,
#  'come': 1,
#  'loudspeakers': 1,
#  'headphones': 1,
#  '2000s': 1,
#  'haptic': 1,
#  'vibration': 1,
#  'creating': 1,
#  'force': 1,
#  'feedback': 1,
#  'peripherals': 1,
#  'headsets': 1,
#  'electronic': 1,
#  'systems': 1,
#  'play': 1,
#  'video': 3,
#  'called': 1,
#  'Video': 1,
#  'developed': 1,
#  'released': 1,
#  'available': 2,
#  'Specialized': 1,
#  'arcade': 1,
#  'present': 1,
#  'large': 1,
#  'typically': 1,
#  'coin': 1,
#  'operated': 1,
#  'chassis': 1,
#  'common': 1,
#  '1980s': 1,
#  'arcades': 1,
#  'declined': 1,
#  'popularity': 1,
#  'affordable': 1,
#  'dedicated': 1,
#  'consoles': 1,
#  'general': 1,
#  'purpose': 1,
#  'computers': 1,
#  'like': 1,
#  'laptop': 1,
#  'desktop': 1,
#  'handheld': 1,
#  'computing': 1}

# %%
max_frequency = max(word_frequencies.values())
max_frequency
# Out:
# 5

# %%
for word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word]/max_frequency

word_frequencies
# Out:
# {'self': 0.2,
#  'study': 0.2,
#  'lessons': 0.2,
#  'section': 0.2,
#  'written': 0.2,
#  'organised': 0.2,
#  'according': 0.2,
#  'levels': 0.2,
#  'Common': 0.4,
#  'European': 0.2,
#  'Framework': 0.2,
#  'Reference': 0.2,
#  'languages': 0.2,
#  'CEFR': 0.2,
#  'different': 0.2,
#  'types': 0.2,
#  'texts': 0.2,
#  'interactive': 0.2,
#  'exercises': 0.2,
#  'practise': 0.2,
#  'reading': 0.2,
#  'skills': 0.2,
#  'need': 0.2,
#  'studies': 0.2,
#  'ahead': 0.2,
#  'work': 0.2,
#  'communicate': 0.2,
#  'English': 0.2,
#  'free': 0.2,
#  'time': 0.2,
#  'story': 0.2,
#  'good': 0.2,
#  'exciting': 0.2,
#  'sudden': 0.2,
#  'end': 0.2,
#  'thought': 0.2,
#  'text': 0.4,
#  'message': 0.2,
#  'joke': 0.2,
#  's': 0.2,
#  'exactly': 0.2,
#  'reason': 0.2,
#  'think': 0.2,
#  'kind': 0.2,
#  'interesting': 0.2,
#  'question': 0.2,
#  'awesome': 0.2,
#  'difficult': 0.2,
#  'input': 0.2,
#  'device': 0.4,
#  'games': 1.0,
#  'game': 1.0,
#  'controller': 0.2,
#  'varies': 0.2,
#  'platforms': 1.0,
#  'controllers': 0.2,
#  'include': 0.6,
#  'gamepads': 0.2,
#  'joysticks': 0.2,
#  'mouse': 0.2,
#  'devices': 0.8,
#  'keyboards': 0.2,
#  'touchscreens': 0.2,
#  'mobile': 0.2,
#  'person': 0.2,
#  'body': 0.2,
#  'Kinect': 0.2,
#  'sensor': 0.2,
#  'Players': 0.2,
#  'view': 0.2,
#  'display': 0.4,
#  'television': 0.2,
#  'computer': 0.2,
#  'monitor': 0.2,
#  'virtual': 0.4,
#  'reality': 0.4,
#  'head': 0.2,
#  'mounted': 0.2,
#  'goggles': 0.2,
#  'sound': 0.2,
#  'effects': 0.4,
#  'music': 0.2,
#  'voice': 0.2,
#  'actor': 0.2,
#  'lines': 0.2,
#  'come': 0.2,
#  'loudspeakers': 0.2,
#  'headphones': 0.2,
#  '2000s': 0.2,
#  'haptic': 0.2,
#  'vibration': 0.2,
#  'creating': 0.2,
#  'force': 0.2,
#  'feedback': 0.2,
#  'peripherals': 0.2,
#  'headsets': 0.2,
#  'electronic': 0.2,
#  'systems': 0.2,
#  'play': 0.2,
#  'video': 0.6,
#  'called': 0.2,
#  'Video': 0.2,
#  'developed': 0.2,
#  'released': 0.2,
#  'available': 0.4,
#  'Specialized': 0.2,
#  'arcade': 0.2,
#  'present': 0.2,
#  'large': 0.2,
#  'typically': 0.2,
#  'coin': 0.2,
#  'operated': 0.2,
#  'chassis': 0.2,
#  'common': 0.2,
#  '1980s': 0.2,
#  'arcades': 0.2,
#  'declined': 0.2,
#  'popularity': 0.2,
#  'affordable': 0.2,
#  'dedicated': 0.2,
#  'consoles': 0.2,
#  'general': 0.2,
#  'purpose': 0.2,
#  'computers': 0.2,
#  'like': 0.2,
#  'laptop': 0.2,
#  'desktop': 0.2,
#  'handheld': 0.2,
#  'computing': 0.2}

# %%
sentence_tokens = [sent for sent in doc.sents]
sentence_tokens
# Out:
# [The self-study lessons in this section are written and organised according to the levels of the Common European Framework of Reference for languages (CEFR).,
#  There are different types of texts and interactive exercises that practise the reading skills you need to do well in your studies, to get ahead at work and to communicate in English in your free time.,
#  This story was really good and exciting with an sudden end.,
#  I thought the text message was a joke, thats exactly the reason why I think this kind of text is really interesting.,
#  The question is really awesome and difficult.,
#  The input device used for games, the game controller, varies across platforms.,
#  Common controllers include gamepads, joysticks, mouse devices, keyboards, the touchscreens of mobile devices, or even a person's body, using a Kinect sensor.,
#  Players view the game on a display device such as a television or computer monitor or sometimes on virtual reality head-mounted display goggles.,
#  There are often game sound effects, music and voice actor lines which come from loudspeakers or headphones.,
#  Some games in the 2000s include haptic, vibration-creating effects, force feedback peripherals and virtual reality headsets.,
#  The electronic systems used to play video games are called platforms.,
#  Video games are developed and released for one or several platforms and may not be available on others.,
#  Specialized platforms such as arcade games, which present the game in a large, typically coin-operated chassis, were common in the 1980s in video arcades, but declined in popularity as other, more affordable platforms became available. ,
#  These include dedicated devices such as video game consoles, as well as general-purpose computers like a laptop, desktop or handheld computing devices.]

# %%
len(sentence_tokens)
# Out:
# 14

# %%
sentence_scores ={}
for sent in sentence_tokens:
    for word in sent:
        if word.text.lower() in word_frequencies.keys():
            if sent not in sentence_scores.keys():
                sentence_scores[sent] = word_frequencies[word.text.lower()]
            else:
                sentence_scores[sent] += word_frequencies[word.text.lower()]

# %%
sentence_scores
# Out:
# {The self-study lessons in this section are written and organised according to the levels of the Common European Framework of Reference for languages (CEFR).: 1.9999999999999998,
#  There are different types of texts and interactive exercises that practise the reading skills you need to do well in your studies, to get ahead at work and to communicate in English in your free time.: 3.0000000000000004,
#  This story was really good and exciting with an sudden end.: 1.0,
#  I thought the text message was a joke, thats exactly the reason why I think this kind of text is really interesting.: 2.6,
#  The question is really awesome and difficult.: 0.6000000000000001,
#  The input device used for games, the game controller, varies across platforms.: 4.0,
#  Common controllers include gamepads, joysticks, mouse devices, keyboards, the touchscreens of mobile devices, or even a person's body, using a Kinect sensor.: 4.400000000000001,
#  Players view the game on a display device such as a television or computer monitor or sometimes on virtual reality head-mounted display goggles.: 4.400000000000001,
#  There are often game sound effects, music and voice actor lines which come from loudspeakers or headphones.: 3.000000000000001,
#  Some games in the 2000s include haptic, vibration-creating effects, force feedback peripherals and virtual reality headsets.: 4.4,
#  The electronic systems used to play video games are called platforms.: 3.4000000000000004,
#  Video games are developed and released for one or several platforms and may not be available on others.: 3.4,
#  Specialized platforms such as arcade games, which present the game in a large, typically coin-operated chassis, were common in the 1980s in video arcades, but declined in popularity as other, more affordable platforms became available. : 7.600000000000002,
#  These include dedicated devices such as video game consoles, as well as general-purpose computers like a laptop, desktop or handheld computing devices.: 5.800000000000002}

# %%
from heapq import nlargest

# %%
select_length = int(len(sentence_tokens)* 0.3)
select_length                   #to give 4 sentences..
# Out:
# 4

# %%
summary = nlargest(select_length, sentence_scores, key = sentence_scores.get)

# %%
summary
# Out:
# [Specialized platforms such as arcade games, which present the game in a large, typically coin-operated chassis, were common in the 1980s in video arcades, but declined in popularity as other, more affordable platforms became available. ,
#  These include dedicated devices such as video game consoles, as well as general-purpose computers like a laptop, desktop or handheld computing devices.,
#  Common controllers include gamepads, joysticks, mouse devices, keyboards, the touchscreens of mobile devices, or even a person's body, using a Kinect sensor.,
#  Players view the game on a display device such as a television or computer monitor or sometimes on virtual reality head-mounted display goggles.]

# %%
#combining above sentences
final_summary = [word.text for word in summary]
final_summary
# Out:
# ['Specialized platforms such as arcade games, which present the game in a large, typically coin-operated chassis, were common in the 1980s in video arcades, but declined in popularity as other, more affordable platforms became available. \n',
#  'These include dedicated devices such as video game consoles, as well as general-purpose computers like a laptop, desktop or handheld computing devices.',
#  "Common controllers include gamepads, joysticks, mouse devices, keyboards, the touchscreens of mobile devices, or even a person's body, using a Kinect sensor.\n",
#  'Players view the game on a display device such as a television or computer monitor or sometimes on virtual reality head-mounted display goggles.']

# %%
summary = ' '.join(final_summary)
summary
# Out:
# "Specialized platforms such as arcade games, which present the game in a large, typically coin-operated chassis, were common in the 1980s in video arcades, but declined in popularity as other, more affordable platforms became available. \n These include dedicated devices such as video game consoles, as well as general-purpose computers like a laptop, desktop or handheld computing devices. Common controllers include gamepads, joysticks, mouse devices, keyboards, the touchscreens of mobile devices, or even a person's body, using a Kinect sensor.\n Players view the game on a display device such as a television or computer monitor or sometimes on virtual reality head-mounted display goggles."
